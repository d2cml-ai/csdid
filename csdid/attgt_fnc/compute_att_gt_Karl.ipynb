# %%
pip install git+https://github.com/d2cml-ai/DRDID

# %%
import numpy as np, pandas as pd
import patsy 
from drdid import drdid, reg_did, ipwd_did

from csdid.utils.bmisc import panel2cs2

# %%
# data Struct
# output = {
#   "att" : []
#   'group': []
#   'year': []
#   'post ': []
# }

# %%
fml = patsy.dmatrices # Matriz de diseño 
def compute_att_gt(dp, est_method = "dr", base_period = 'varying'): # Calculo del ATT por grupo y tiempo
  # dp → Diccionario
  # est_method → Método did
  # base_perid → Periodo base de la estimación
  yname = dp['yname']
  tname = dp['tname']
  idname = dp['idname']
  xformla = dp['xformla']
  data = dp['data']
  weights_name = dp['weights_name']
  # base_period = dp['base_period']
  panel = dp['panel']
  true_rep_cross_section = dp['true_rep_cross_section']
  control_group = dp['control_group']
  anticipation = dp['anticipation']
  gname = dp['gname']
  n = dp['n']
  nT = dp['nT']
  nG = dp['nG']
  tlist = dp['tlist']
  glist = dp['glist']

  tlist_len, tfac = len(tlist), 0 # Ajuste de longitud de tlit
  if base_period != 'universal': # Si la base del periodo no es universal
    tlist_len = tlist_len - 1 # Ajuste 
    tfac = 1 # Factor de correción

  #inf_func = [] # Almacenamiento de reesultados del ATT
  #att_est, group, year, post_array = [], [], [], []

  return (dp)

# %%
dta = pd.read_csv("https://raw.githubusercontent.com/d2cml-ai/csdid/main/data/sim_data.csv")
dta.head()
# Out:
#    G         X  id  cluster  period         Y  treat
# 0  3 -0.876233   1        5       1  5.562556      1
# 1  3 -0.876233   1        5       2  4.349213      1
# 2  3 -0.876233   1        5       3  7.134037      1
# 3  3 -0.876233   1        5       4  6.243056      1
# 4  2 -0.873848   2       36       1 -3.659387      1

# %%
# Preparar el diccionario 'dp' con los datos necesarios para la función compute_att_gt
dp = {
    'yname': 'y',  # Nombre de la columna dependiente
    'tname': 'time',  # Columna que contiene el tiempo
    'idname': 'id',  # Columna que contiene los identificadores
    'xformla': '1',  # Fórmula para las covariables (si las tienes, puedes especificarlas)
    'data': dta,  # El dataframe que cargaste
    'weights_name': None,  # Si tienes pesos, puedes agregarlo aquí
    'panel': True,  # Especifica si los datos están en formato de panel
    'true_rep_cross_section': False,  # Define si es necesario calcular la sección cruzada representativa
    'control_group': 'g0',  # Grupo de control (esto depende de los datos que estés usando)
    'anticipation': 0,  # Período de anticipación
    'gname': 'g',  # Nombre de la columna que contiene los grupos
    'n': dta.shape[0],  # Número de observaciones
    'nT': len(dta['time'].unique()),  # Número de períodos de tiempo
    'nG': len(dta['g'].unique()),  # Número de grupos
    'tlist': dta['time'].unique(),  # Lista de los tiempos únicos
    'glist': dta['g'].unique()  # Lista de los grupos únicos
}

# Ahora puedes llamar a la función compute_att_gt y pasar el diccionario dp
result = compute_att_gt(dp)

# Ver los resultados
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 15
# ...
