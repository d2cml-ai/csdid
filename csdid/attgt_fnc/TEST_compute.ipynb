# %%
import sys
sys.path.append('C:/Users/Lenovo/Documents/GitHub/csdid/csdid/attgt_fnc')

from compute_att_gt import compute_att_gt

# %%
import numpy as np, pandas as pd

# %%
# Leer los datos
data = pd.read_csv("https://raw.githubusercontent.com/d2cml-ai/csdid/main/data/sim_data.csv")

# %%
# Prepara el diccionario con los parámetros
dp = {
    'yname': 'Y',
    'tname': 'treat',
    'idname': 'id',
    'xformla': 'X',
    'data': data,
    'weights_name': None,  # Si no tienes pesos
    'panel': True,  # Si es un panel de datos
    'true_rep_cross_section': False,  # Suponiendo que no es una muestra representativa
    'control_group': 'notyettreated',  # Grupo de control
    'anticipation': 0,  # Sin anticipación
    'gname': 'G',  # Nombre del grupo
    'n': len(data),
    'nT': data['period'].nunique(),  # Número de periodos
    'nG': data['G'].nunique(),  # Número de grupos
    'tlist': sorted(data['period'].unique()),  # Lista de periodos
    'glist': sorted(data['G'].unique())  # Lista de grupos
}

# Ejecuta tu función
compute_att_gt(dp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Lenovo\Documents\GitHub\csdid\csdid\attgt_fnc\compute_att_gt.py:70, in compute_att_gt(dp, est_method, base_period)
#      38   return dp
#      40   """
#      41   tlist_len, tfac = len(tlist), 0
#      42   if base_period != 'universal':
#      43     tlist_len = tlist_len - 1
#      44     tfac = 1
#      45
#      46   inf_func = []
#      47
#      48   att_est, group, year, post_array = [], [], [], []
#      49
#      50   def add_att_data(att = 0, pst = 0, inf_f = []):
#      51     inf_func.append(inf_f)
#      52     att_est.append(att)
#      53     group.append(g)
#      54     year.append(tn)
#      55     post_array.append(pst)
#      56
#      57   never_treated = control_group == 'nevertreated'
#      58   if never_treated:
#      59     data = data.assign(C = 1 * (data[gname] == 0))
#      60   data = data.assign(y_main = data[yname])
#      61
#      62   # g, t = glist[0], tlist[0]
#      63
#      64   for _, g, in enumerate(glist):
#      65     # g = glist[1]
#      66     G_main = (data[gname] == g)
#      67     data = data.assign(G_m = 1 * G_main)
#      68
#      69     for t_i in range(tlist_len):
# ---> 70       pret = t_i
#      71       tn = tlist[t_i + tfac]
#      72       if base_period == 'universal' or g < tn:
#      73         try:
#      74           pret = np.where(tlist + anticipation < g)[0][-1]
#      75         except:
#      76           raise f"There are no pre-treatment periods for the group first treated at {g}\nUnits from this group are dropped"
#      77           # break
#      78
#      79
#      80       if base_period == 'universal':
#      81         if pret == tn:
#      82           add_att_data()
#      83
#      84       if not never_treated:
#      85         n1 = data[gname] == 0
#      86         n2 = (data[gname] > (tlist[np.max([t_i, pret]) + tfac]) + anticipation)
#      87         n3 = np.where(data[gname] != glist[g], True, False)
#      88         row_eval = n1 | n2 & n3
#      89         data = data.assign(C = 1 * row_eval)
#      90
#      91       post_treat = 1 * (g <= tn)
#      92       disdat = data[(data[tname] == tn) | (data[tname] == tlist[pret])]
#      93
#      94       if panel:
#      95         disdat = panel2cs2(disdat, yname, idname, tname)
#      96         disdat = disdat.dropna()
#      97         n = len(disdat)
#      98         dis_idx = np.array(disdat.G_m == 1) | np.array(disdat.C == 1)
#      99         disdat = disdat.loc[dis_idx, :]
#     100         n1 = len(disdat)
#     101         G = disdat.G_m
#     102         C = disdat.C
#     103         w = disdat.w
#     104
#     105         ypre = disdat.y0 if tn > pret else disdat.y1
#     106         ypost = disdat.y0 if tn < pret else disdat.y1
#     107         _, covariates = fml(xformla, data = disdat, return_type = 'dataframe')
#     108
#     109         G, C, w, ypre = map(np.array, [G, C, w, ypre])
#     110         ypost, covariates = map(np.array, [ypost, covariates])
#     111
#     112         if callable(est_method):
#     113           est_att_f = est_method
#     114         elif est_method == "reg":
#     115           est_att_f = reg_did.reg_did_panel
#     116         elif est_method == "ipw":
#     117           est_att_f = ipwd_did.std_ipw_did_panel
#     118         elif est_method == "dr":
#     119           est_att_f = drdid.drdid_panel
#     120
#     121         att_gt, att_inf_func = est_att_f(ypost, ypre, G, i_weights=w, covariates=covariates)
#     122
#     123         inf_zeros = np.zeros(n)
#     124         att_inf = n / n1 * att_inf_func
#     125         inf_zeros[dis_idx] = att_inf
#     126
#     127         add_att_data(att_gt, inf_f=inf_zeros)
#     128
#     129       if not panel:
#     130         right_ids = np.array(disdat.query('(G_m == 1) or (C == 1)').rowid.to_numpy())
#     131         dis_idx = (data['rowid'].isin(right_ids)) &\
#     132           ((data[tname] == tlist[t_i + tfac]) |\
#     133             (data[tname] == tlist[pret]))
#     134
#     135         disdat = data.loc[dis_idx]
#     136
#     137         G = disdat.G_m.to_numpy()
#     138         C = disdat.C.to_numpy()
#     139         Y = disdat[yname].to_numpy()
#     140         post = 1 * (disdat[tname] == tlist[t_i + tfac]).to_numpy()
#     141         w = disdat.w.to_numpy()
#     142
#     143         # G, C, Y, post, w = map(np.array, [G, C, Y, post, w])
#     144
#     145
#     146         n1 = sum(G + C)
#     147
#     148         skip_this_att_gt = False
#     149         if np.sum(G * post) == 0:
#     150           print(f"No units in group {g} in time period {tn}")
#     151           skip_this_att_gt = True
#     152
#     153         if np.sum(G * (1 - post)) == 0:
#     154           print(f"No units in group {g} in time period {tn}")
#     155           skip_this_att_gt = True
#     156
#     157         if np.sum(C * post) == 0:
#     158           print(f"No available control units for group {g} in time period {tn}")
#     159           skip_this_att_gt = True
#     160
#     161         if np.sum(C * (1 - post)) == 0:
#     162           print(f"No available control units for group {g} in time period {tn}")
#     163           skip_this_att_gt = True
#     164
#     165         if skip_this_att_gt:
#     166           add_att_data()
#     167
#     168         try:
#     169           _, covariates = fml(xformla, data = disdat, return_type = 'dataframe')
#     170           covariates = np.array(covariates)
#     171         except:
#     172           y_str, x_str = xformla.split("~")
#     173           xs1 = x_str.split('+')
#     174           xs1_col_names = [x.strip() for x in xs1 if x.strip() != '1']
#     175           n_dis = len(disdat)
#     176           ones = np.ones((n_dis, 1))
#     177           try:
#     178             covariates = disdat[xs1_col_names].to_numpy()
#     179             covariates = np.append(covariates, ones, axis=1)
#     180           except:
#     181             covariates = ones
#     182
#     183
#     184
#     185         if callable(est_method):
#     186           est_att_f = est_method
#     187         elif est_method == "reg":
#     188           est_att_f = reg_did.reg_did_rc
#     189         elif est_method == "ipw":
#     190           est_att_f = ipwd_did.std_ipw_did_rc
#     191         elif est_method == "dr":
#     192           est_att_f = drdid.drdid_rc
#     193         att_gt, att_inf_func = est_att_f(y=Y, post=post, D = G, i_weights=w, covariates=covariates)
#     194
#     195         inf_func_df = pd.DataFrame(
#     196           {
#     197             "inf_func": att_inf_func,
#     198             "right_ids": right_ids
#     199           }
#     200         )
#     201         inf_zeros = np.zeros(n)
#     202         aggte_infffuc = inf_func_df.groupby('right_ids').inf_func.sum()
#     203         try:
#     204           dis_idx1 = np.isin(data['rowid'].unique(), aggte_infffuc.index.to_numpy())
#     205         except:
#     206           dis_idx1 = np.isin(data['rowid'].unique().to_numpy(), aggte_infffuc.index.to_numpy())
#     207         inf_zeros[dis_idx1] = np.array(aggte_infffuc)
#     208
#     209         add_att_data(att_gt, pst = post_treat, inf_f=inf_zeros)
#     210         # print(att_est)
#     211
#     212   output = {
#     213     'group': group ,
#     214     'year': year,
#     215     "att" : att_est,
#     216     'post ': post_array
#     217   }
#     218   return (output, np.array(inf_func))
#     219
#     220 """
#
# TypeError: can only concatenate list (not "int") to list
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 22
#       2 dp = {
#       3     'yname': 'Y',
#       4     'tname': 'treat',
#    (...)
#      18     'glist': sorted(data['G'].unique())  # Lista de grupos
#      19 }
#      21 # Ejecuta tu función
# ---> 22 compute_att_gt(dp)
#
# File c:\Users\Lenovo\Documents\GitHub\csdid\csdid\attgt_fnc\compute_att_gt.py:72, in compute_att_gt(dp, est_method, base_period)
#      36   glist = dp['glist']
#      38   return dp
#      40   """
#      41   tlist_len, tfac = len(tlist), 0
#      42   if base_period != 'universal':
#      43     tlist_len = tlist_len - 1
#      44     tfac = 1
#      45
#      46   inf_func = []
#      47
#      48   att_est, group, year, post_array = [], [], [], []
#      49
#      50   def add_att_data(att = 0, pst = 0, inf_f = []):
#      51     inf_func.append(inf_f)
#      52     att_est.append(att)
#      53     group.append(g)
#      54     year.append(tn)
#      55     post_array.append(pst)
#      56
#      57   never_treated = control_group == 'nevertreated'
#      58   if never_treated:
#      59     data = data.assign(C = 1 * (data[gname] == 0))
#      60   data = data.assign(y_main = data[yname])
#      61
#      62   # g, t = glist[0], tlist[0]
#      63
#      64   for _, g, in enumerate(glist):
#      65     # g = glist[1]
#      66     G_main = (data[gname] == g)
#      67     data = data.assign(G_m = 1 * G_main)
#      68
#      69     for t_i in range(tlist_len):
#      70       pret = t_i
#      71       tn = tlist[t_i + tfac]
# ---> 72       if base_period == 'universal' or g < tn:
#      73         try:
#      74           pret = np.where(tlist + anticipation < g)[0][-1]
#      75         except:
#      76           raise f"There are no pre-treatment periods for the group first treated at {g}\nUnits from this group are dropped"
#      77           # break
#      78
#      79
#      80       if base_period == 'universal':
#      81         if pret == tn:
#      82           add_att_data()
#      83
#      84       if not never_treated:
#      85         n1 = data[gname] == 0
#      86         n2 = (data[gname] > (tlist[np.max([t_i, pret]) + tfac]) + anticipation)
#      87         n3 = np.where(data[gname] != glist[g], True, False)
#      88         row_eval = n1 | n2 & n3
#      89         data = data.assign(C = 1 * row_eval)
#      90
#      91       post_treat = 1 * (g <= tn)
#      92       disdat = data[(data[tname] == tn) | (data[tname] == tlist[pret])]
#      93
#      94       if panel:
#      95         disdat = panel2cs2(disdat, yname, idname, tname)
#      96         disdat = disdat.dropna()
#      97         n = len(disdat)
#      98         dis_idx = np.array(disdat.G_m == 1) | np.array(disdat.C == 1)
#      99         disdat = disdat.loc[dis_idx, :]
#     100         n1 = len(disdat)
#     101         G = disdat.G_m
#     102         C = disdat.C
#     103         w = disdat.w
#     104
#     105         ypre = disdat.y0 if tn > pret else disdat.y1
#     106         ypost = disdat.y0 if tn < pret else disdat.y1
#     107         _, covariates = fml(xformla, data = disdat, return_type = 'dataframe')
#     108
#     109         G, C, w, ypre = map(np.array, [G, C, w, ypre])
#     110         ypost, covariates = map(np.array, [ypost, covariates])
#     111
#     112         if callable(est_method):
#     113           est_att_f = est_method
#     114         elif est_method == "reg":
#     115           est_att_f = reg_did.reg_did_panel
#     116         elif est_method == "ipw":
#     117           est_att_f = ipwd_did.std_ipw_did_panel
#     118         elif est_method == "dr":
#     119           est_att_f = drdid.drdid_panel
#     120
#     121         att_gt, att_inf_func = est_att_f(ypost, ypre, G, i_weights=w, covariates=covariates)
#     122
#     123         inf_zeros = np.zeros(n)
#     124         att_inf = n / n1 * att_inf_func
#     125         inf_zeros[dis_idx] = att_inf
#     126
#     127         add_att_data(att_gt, inf_f=inf_zeros)
#     128
#     129       if not panel:
#     130         right_ids = np.array(disdat.query('(G_m == 1) or (C == 1)').rowid.to_numpy())
#     131         dis_idx = (data['rowid'].isin(right_ids)) &\
#     132           ((data[tname] == tlist[t_i + tfac]) |\
#     133             (data[tname] == tlist[pret]))
#     134
#     135         disdat = data.loc[dis_idx]
#     136
#     137         G = disdat.G_m.to_numpy()
#     138         C = disdat.C.to_numpy()
#     139         Y = disdat[yname].to_numpy()
#     140         post = 1 * (disdat[tname] == tlist[t_i + tfac]).to_numpy()
#     141         w = disdat.w.to_numpy()
#     142
#     143         # G, C, Y, post, w = map(np.array, [G, C, Y, post, w])
#     144
#     145
#     146         n1 = sum(G + C)
#     147
#     148         skip_this_att_gt = False
#     149         if np.sum(G * post) == 0:
#     150           print(f"No units in group {g} in time period {tn}")
#     151           skip_this_att_gt = True
#     152
#     153         if np.sum(G * (1 - post)) == 0:
#     154           print(f"No units in group {g} in time period {tn}")
#     155           skip_this_att_gt = True
#     156
#     157         if np.sum(C * post) == 0:
#     158           print(f"No available control units for group {g} in time period {tn}")
#     159           skip_this_att_gt = True
#     160
#     161         if np.sum(C * (1 - post)) == 0:
#     162           print(f"No available control units for group {g} in time period {tn}")
#     163           skip_this_att_gt = True
#     164
#     165         if skip_this_att_gt:
#     166           add_att_data()
#     167
#     168         try:
#     169           _, covariates = fml(xformla, data = disdat, return_type = 'dataframe')
#     170           covariates = np.array(covariates)
#     171         except:
#     172           y_str, x_str = xformla.split("~")
#     173           xs1 = x_str.split('+')
#     174           xs1_col_names = [x.strip() for x in xs1 if x.strip() != '1']
#     175           n_dis = len(disdat)
#     176           ones = np.ones((n_dis, 1))
#     177           try:
#     178             covariates = disdat[xs1_col_names].to_numpy()
#     179             covariates = np.append(covariates, ones, axis=1)
#     180           except:
#     181             covariates = ones
#     182
#     183
#     184
#     185         if callable(est_method):
#     186           est_att_f = est_method
#     187         elif est_method == "reg":
#     188           est_att_f = reg_did.reg_did_rc
#     189         elif est_method == "ipw":
#     190           est_att_f = ipwd_did.std_ipw_did_rc
#     191         elif est_method == "dr":
#     192           est_att_f = drdid.drdid_rc
#     193         att_gt, att_inf_func = est_att_f(y=Y, post=post, D = G, i_weights=w, covariates=covariates)
#     194
#     195         inf_func_df = pd.DataFrame(
#     196           {
#     197             "inf_func": att_inf_func,
#     198             "right_ids": right_ids
#     199           }
#     200         )
#     201         inf_zeros = np.zeros(n)
#     202         aggte_infffuc = inf_func_df.groupby('right_ids').inf_func.sum()
#     203         try:
#     204           dis_idx1 = np.isin(data['rowid'].unique(), aggte_infffuc.index.to_numpy())
#     205         except:
#     206           dis_idx1 = np.isin(data['rowid'].unique().to_numpy(), aggte_infffuc.index.to_numpy())
#     207         inf_zeros[dis_idx1] = np.array(aggte_infffuc)
#     208
#     209         add_att_data(att_gt, pst = post_treat, inf_f=inf_zeros)
#     210         # print(att_est)
#     211
#     212   output = {
#     213     'group': group ,
#     214     'year': year,
#     215     "att" : att_est,
#     216     'post ': post_array
#     217   }
#     218   return (output, np.array(inf_func))
#     219
#     220 """
#
# TypeError: exceptions must derive from BaseException
